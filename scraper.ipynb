# %% [markdown]
# # # Data Collection
# # **Libraries Used:** ScraperFC, soccerdata
# # **Goal:** Extract player stats for the 2024/2025 season.

# %%
import ScraperFC as sfc
import soccerdata as sd
import pandas as pd

# %% [markdown]
# # ## 1. Initialize Scraper
# # Using ScraperFC to fetch stats from Fbref/Transfermarkt.

# %%
fbref = sd.FBref(leagues="ENG-Premier League", seasons='2526')

stats = fbref.read_player_season_stats(stat_type="standard")
